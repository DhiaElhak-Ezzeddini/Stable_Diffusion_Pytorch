# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/stable-diffusion/encoder.py
# /kaggle/input/stable-diffusion/attention.py
# /kaggle/input/stable-diffusion/inference.ipynb
# /kaggle/input/stable-diffusion/ddpm.py
# /kaggle/input/stable-diffusion/add_noise.ipynb
# /kaggle/input/stable-diffusion/model_loader.py
# /kaggle/input/stable-diffusion/clip.py
# /kaggle/input/stable-diffusion/decoder.py
# /kaggle/input/stable-diffusion/pipeline.py
# /kaggle/input/stable-diffusion/model_converter.py
# /kaggle/input/stable-diffusion/diffusion.py
# /kaggle/input/stable-diffusion/demo.ipynb
# /kaggle/input/stable-diffusion/data/merges.txt
# /kaggle/input/stable-diffusion/data/v1-5-pruned-emaonly.ckpt
# /kaggle/input/stable-diffusion/data/vocab.json

# %%
import sys
sys.path.append("/kaggle/input/stable-diffusion")

# %%
import pipeline
import model_loader
from PIL import Image
from transformers import CLIPTokenizer
import torch

DEVICE = "cpu"
ALLOW_CUDA = True
if torch.cuda.is_available()  and ALLOW_CUDA : 
    DEVICE = "cuda"
print(f"Using {DEVICE}")
# Out:
# Using cuda

# %%
tokenizer = CLIPTokenizer('/kaggle/input/stable-diffusion/data/vocab.json' , merges_file="/kaggle/input/stable-diffusion/data/merges.txt") 
model_file = "/kaggle/input/stable-diffusion/data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_weights(model_file,device=DEVICE)

# %%
### text to image ###
prompt = "A futuristic city skyline at sunset, with glowing neon signs, flying cars, and reflective glass buildings,in the style of cyberpunk, high detail, dramatic lighting, ultra realistic"
uncond_prompt = ""
do_cfg = True
cfg_scale = 8

input_image = None
### Image to image ###
image_path = ''
#input_image = Image.open(image_path)
strength = 0.9

## Sampler

sampler = "ddpm"
num_inference_steps = 50
seed = 42
output_image = pipeline.generate(
    prompt = prompt,
    uncond_prompt = uncond_prompt,
    input_image = input_image,
    strength = strength,
    do_cfg = do_cfg,
    cfg_scale = cfg_scale,
    sampler_name = sampler,
    n_inference_steps = num_inference_steps,
    seed = seed,
    models = models,
    device = DEVICE,
    idle_device = "cpu",
    tokenizer = tokenizer,
)
Image.fromarray(output_image)
# Out:
# 100%|██████████| 50/50 [00:14<00:00,  3.38it/s]
# (1, 512, 512, 3)
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "A portrait of a man with short tousled hair and a stubble beard, wearing a denim jacket, soft cinematic lighting, looking into the distance, high detail, realistic photography, 85mm lens, shallow depth of field, moody atmosphere"

output_image = pipeline.generate(
    prompt = prompt,
    uncond_prompt = uncond_prompt,
    input_image = input_image,
    strength = strength,
    do_cfg = do_cfg,
    cfg_scale = cfg_scale,
    sampler_name = sampler,
    n_inference_steps = num_inference_steps,
    seed = seed,
    models = models,
    device = DEVICE,
    idle_device = "cpu",
    tokenizer = tokenizer,
)
Image.fromarray(output_image)
# Out:
# 100%|██████████| 50/50 [00:14<00:00,  3.38it/s]
# (1, 512, 512, 3)
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "Aerial photograph of a winding river snaking through a lush green landscape, with dramatic curves and oxbows. The scene includes forests, farmlands, and scattered clouds casting soft shadows on the terrain. High-resolution, natural colors, National Geographic style."
output_image = pipeline.generate(
    prompt = prompt,
    uncond_prompt = uncond_prompt,
    input_image = input_image,
    strength = strength,
    do_cfg = do_cfg,
    cfg_scale = cfg_scale,
    sampler_name = sampler,
    n_inference_steps = num_inference_steps,
    seed = seed,
    models = models,
    device = DEVICE,
    idle_device = "cpu",
    tokenizer = tokenizer,
)
Image.fromarray(output_image)
# Out:
# 100%|██████████| 50/50 [00:14<00:00,  3.38it/s]
# (1, 512, 512, 3)
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "Impressionist-style landscape of a Japanese garden in autumn. A delicate wooden bridge spans across a koi pond filled with colorful fish. Warm autumn foliage surrounds the scene, creating a peaceful, painterly atmosphere with natural textures and soft reflections on the water."
output_image = pipeline.generate(
    prompt = prompt,
    uncond_prompt = uncond_prompt,
    input_image = input_image,
    strength = strength,
    do_cfg = do_cfg,
    cfg_scale = cfg_scale,
    sampler_name = sampler,
    n_inference_steps = num_inference_steps,
    seed = seed,
    models = models,
    device = DEVICE,
    idle_device = "cpu",
    tokenizer = tokenizer,
)
Image.fromarray(output_image)
# Out:
# 100%|██████████| 50/50 [00:14<00:00,  3.38it/s]
# (1, 512, 512, 3)
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "Aerial view of a dense modern city filled with tall skyscrapers, busy roads, cars, and green rooftop gardens. The scene is captured at sunset with golden hour lighting reflecting off glass buildings. High detail, photorealistic, drone perspective."
output_image = pipeline.generate(
    prompt = prompt,
    uncond_prompt = uncond_prompt,
    input_image = input_image,
    strength = strength,
    do_cfg = do_cfg,
    cfg_scale = cfg_scale,
    sampler_name = sampler,
    n_inference_steps = num_inference_steps,
    seed = seed,
    models = models,
    device = DEVICE,
    idle_device = "cpu",
    tokenizer = tokenizer,
)
Image.fromarray(output_image)
# Out:
# 100%|██████████| 50/50 [00:14<00:00,  3.38it/s]
# (1, 512, 512, 3)
# <PIL.Image.Image image mode=RGB size=512x512>
